# %%
# !pip install pysr
import pandas as pd
import numpy as np
from pysr import PySRRegressor
import matplotlib.pyplot as plt
import sympy
import pandas as pd

# Load the dataset
df = pd.read_csv("./dose_response_parameters.csv")


y = df['P_Km_relative'].values * 1  # 放大y，避免loss过小带来的精度问题

X = np.column_stack([df['E'], df['k']])
# log transform to X
X = np.column_stack([np.log(df['E'].values + 1e-8), np.log(df['k'].values + 1e-8)])


# X = df['P_Vmax_relative'].values.reshape(-1, 1)

# It's a good practice to check the shapes of the data
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)

# Let's inspect the first few rows to ensure the data is loaded correctly
print("\nFirst 5 rows of the input data (X):")
print(pd.DataFrame(X, columns=['E', 'k']).head())
print("\nFirst 5 values of the output data (y):")
print(y[:5])

# check for NaN or Inf values in X and y
print(np.isnan(X).any(), np.isinf(X).any(), np.max(np.abs(X)))
print(np.isnan(y).any(), np.isinf(y).any(), np.max(np.abs(y)))
# Out:
# Shape of X: (21, 2)
# Shape of y: (21,)
#
# First 5 rows of the input data (X):
#           E         k
# 0  7.808307  1.218405
# 1  7.608937  0.406188
# 2  7.877354  0.599790
# 3  7.805786  0.581259
# 4  7.623823  0.502339
#
# First 5 values of the output data (y):
# [0.94971704 0.75842551 1.29493945 1.33593881 1.16693506]
# False False 7.984403532244132
# False False 2.76022757841034

# %%
model = PySRRegressor(
    niterations=100,
    populations=20,
    binary_operators=["+", "*", "/", "-"],
    unary_operators=["exp", "log", "tanh", "inv",  "square", "cube"],
    complexity_of_operators={"exp": 1, "log": 1, "tanh": 2, "inv": 1, "square": 2, "cube": 2},
    verbosity=1,
    alpha=1,
    # set maximum running time
    max_evals=4000000
    
)
# Train the model on the entire dataset
# The problem is a single regression problem, not multiple separate ones
model.fit(X, y)
# Out:
# /home/ding_linux/anaconda3/envs/biocircuits/lib/python3.13/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 2.860e+04
# Progress: 172 / 2000 total iterations (8.600%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.584e-01  0.000e+00  y = 1.0814
# 3           2.272e-01  6.441e-02  y = 0.59403 / x₁
# 4           2.193e-01  3.538e-02  y = inv(x₁ + 0.3437)
# 5           1.940e-01  1.229e-01  y = (30.549 / x₀) + -2.9451
# 7           1.675e-01  7.338e-02  y = ((29.569 / x₀) - 2.2001) - x₁
# 10          1.491e-01  3.876e-02  y = exp(square(tanh(log(log(x₀ + -5.0423)))))
# 13          1.223e-01  6.590e-02  y = exp(cube(square(square(log(log(log(x₀ - 2.0133)))))))
# 26          1.201e-01  1.404e-03  y = cube(cube(cube(square(square(inv(cube(tanh((square(squ...
#                                       are(x₀ * 0.13575)) * x₀) + -0.014873))))))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.750e+04
# Progress: 356 / 2000 total iterations (17.800%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.584e-01  0.000e+00  y = 1.0814
# 3           2.272e-01  6.441e-02  y = 0.59403 / x₁
# 4           2.193e-01  3.538e-02  y = inv(x₁ + 0.3437)
# 5           1.940e-01  1.229e-01  y = (30.549 / x₀) + -2.9451
# 7           1.609e-01  9.345e-02  y = ((15.923 / x₀) - 1.5201) / x₁
# 8           1.437e-01  1.128e-01  y = ((58.886 / x₀) - 5.8231) / exp(x₁)
# 10          1.183e-01  9.743e-02  y = exp(square(cube(log(log(x₀ - 4.8054)))))
# 14          1.176e-01  1.422e-03  y = exp(tanh(cube(cube(square(log(log(x₀ + -4.9198)))))))
# 16          1.176e-01  1.192e-06  y = exp(tanh(cube(square(square(square(log(log(-4.9198 + x...
#                                       ₀))))))))
# 18          1.176e-01  2.980e-08  y = exp(cube(tanh(square(square(square(square(log(log(-5.0...
#                                       423 + x₀)))))))))
# 20          1.176e-01  9.239e-07  y = exp(square(cube(square(tanh(cube(square(log(log(x₀ + -...
#                                       5.0423))))))))) - 0.00044837
# 22          1.176e-01  2.807e-05  y = exp(tanh(square(square(square(cube(cube(cube(log(log(x...
#                                       ₀ + -4.9198)))))))))) * 1.0023
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.630e+04
# Progress: 461 / 2000 total iterations (23.050%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.584e-01  0.000e+00  y = 1.0814
# 3           2.272e-01  6.441e-02  y = 0.59403 / x₁
# 4           2.193e-01  3.538e-02  y = inv(x₁ + 0.3437)
# 5           1.940e-01  1.229e-01  y = (30.549 / x₀) + -2.9451
# 7           1.609e-01  9.345e-02  y = ((15.923 / x₀) - 1.5201) / x₁
# 8           1.437e-01  1.128e-01  y = ((58.886 / x₀) - 5.8231) / exp(x₁)
# 10          1.183e-01  9.743e-02  y = exp(square(cube(log(log(x₀ - 4.8054)))))
# 14          1.176e-01  1.422e-03  y = exp(tanh(cube(cube(square(log(log(x₀ + -4.9198)))))))
# 16          1.176e-01  1.804e-04  y = exp(square(tanh(cube(cube(log(log(-4.9198 + x₀))))) * ...
#                                       1.0023))
# 18          1.175e-01  1.737e-04  y = exp(square(cube(tanh(cube(cube(log(log(-4.9198 + x₀)))...
#                                       )) * 1.0023)))
# 19          1.173e-01  2.074e-03  y = exp(tanh(cube(log(cube(log(square(log(x₀ + -5.8806))) ...
#                                       * -0.77654)) * -0.097658)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.720e+04
# Progress: 642 / 2000 total iterations (32.100%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.584e-01  0.000e+00  y = 1.0814
# 3           2.272e-01  6.441e-02  y = 0.59403 / x₁
# 4           2.193e-01  3.538e-02  y = inv(x₁ + 0.3437)
# 5           1.592e-01  3.206e-01  y = inv(log(x₀ + -4.7862))
# 8           1.292e-01  6.939e-02  y = exp(square(log(log(x₀ - 4.8054))))
# 10          1.183e-01  4.433e-02  y = exp(square(cube(log(log(x₀ - 4.8054)))))
# 11          1.114e-01  5.967e-02  y = exp(tanh(log(x₁) * log(log(x₀ + -5.1872))))
# 13          1.102e-01  5.392e-03  y = exp(tanh(log(x₁ + 0.24821) * log(log(-5.2256 + x₀))))
# 17          1.094e-01  1.964e-03  y = exp(tanh(cube(log(log(square(log(x₀ + -5.8806))) * -0....
#                                       77654) * -0.55167)))
# 18          1.040e-01  4.997e-02  y = inv(exp(cube(cube(tanh(log(-1.0855 * log(square(log(x₀...
#                                        + -5.8806)))))))))
# 19          1.034e-01  6.594e-03  y = exp(tanh(log(log(square(log(x₀ + -5.8806))) / -0.77654...
#                                       ) * log(log(x₀ - 4.5646))))
# 20          1.030e-01  3.775e-03  y = inv(exp(tanh(cube(cube(log(log(square(square(log(x₀ + ...
#                                       -5.8806)))) * -0.374))))))
# 21          1.000e-01  2.895e-02  y = exp(tanh(log(log(square(log(x₀ + -5.8806))) / -0.77654...
#                                       ) * (log(log(x₀ - 4.5646)) / 0.61857)))
# 22          9.974e-02  2.883e-03  y = inv(exp(tanh(cube(cube(log(log(square(square(log(x₀ + ...
#                                       -5.8806)))) * (x₁ / -1.4772)))))))
# 25          9.436e-02  1.850e-02  y = exp(tanh(log(log((x₀ / 0.96902) - 4.8054)) * cube(log(...
#                                       log(square(square(log(-5.8806 + x₀)))) * -0.92122))))
# 26          8.590e-02  9.390e-02  y = exp(tanh(log(log((x₀ / 0.96902) - 4.8054)) * cube(log(...
#                                       cube(log(square(log(-5.8806 + x₀))) * inv(-0.92122))))))
# 28          5.788e-02  1.974e-01  y = exp(tanh(log(log((x₀ / 0.96902) - 4.8054)) * cube(cube...
#                                       (log(log(square(square(log(-5.8806 + x₀)))) * inv(-0.92122...
#                                       ))))))
# 29          5.763e-02  4.174e-03  y = exp(tanh(cube(cube(log(log(square(square(log(x₀ + -5.8...
#                                       806)))) * -1.0855))) * (log(log((x₀ / 0.96902) - 4.8054)) ...
#                                       * 1.3082)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.800e+04
# Progress: 835 / 2000 total iterations (41.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.584e-01  0.000e+00  y = 1.0814
# 3           2.272e-01  6.441e-02  y = 0.59403 / x₁
# 4           2.193e-01  3.538e-02  y = inv(x₁ + 0.3437)
# 5           1.592e-01  3.206e-01  y = inv(log(x₀ + -4.7862))
# 7           1.408e-01  6.134e-02  y = exp(inv(cube(x₀ + -5.2448)))
# 8           1.292e-01  8.554e-02  y = exp(square(log(log(x₀ + -4.8064))))
# 9           1.199e-01  7.482e-02  y = exp(inv(cube(cube(x₀ + -5.2474))))
# 10          1.178e-01  1.813e-02  y = exp(cube(square(log(log(x₀ - 4.8087)))))
# 11          1.114e-01  5.533e-02  y = exp(tanh(log(x₁) * log(log(x₀ + -5.1872))))
# 13          1.011e-01  4.856e-02  y = exp(tanh((log(x₁) + x₁) * log(log(x₀ + -5.2394))))
# 15          9.995e-02  5.787e-03  y = exp(tanh(log(log(x₀ + -5.2256)) * ((x₁ * x₁) + log(x₁)...
#                                       )))
# 17          9.750e-02  1.240e-02  y = exp(tanh(log(log(x₀ + -5.2256)) * log(square(x₁ * (1.0...
#                                       895 + x₁)))))
# 19          9.728e-02  1.138e-03  y = exp(tanh(log(log(-5.2256 + x₀)) * log(x₁ * (x₁ + cube(...
#                                       x₁ + x₁)))))
# 21          9.722e-02  3.326e-04  y = exp(tanh(log(x₁ * (x₁ + cube(x₁ - (0.1077 - x₁)))) * l...
#                                       og(log(-5.2256 + x₀))))
# 23          9.459e-02  1.368e-02  y = exp(tanh(cube(log(log(square(log(x₀ + -5.8806))) * -1....
#                                       8121)) * log(log((x₀ / 0.96902) - 4.8054))))
# 25          6.791e-02  1.657e-01  y = exp(tanh(log(log((x₀ / 0.96902) - 4.8054)) * cube(log(...
#                                       cube(log(square(log(x₀ + -5.8806))) * -1.2192)))))
# 27          5.788e-02  7.994e-02  y = exp(tanh(cube(cube(log(log(square(square(log(x₀ + -5.8...
#                                       806)))) * -1.0855))) * log(log((x₀ / 0.96902) - 4.8054))))
# 29          5.689e-02  8.624e-03  y = exp(tanh(cube(cube(log(log(square(square(log(x₀ + -5.8...
#                                       806)))) * -1.0855))) * (log(log((x₀ / 0.96902) - 4.8054)) ...
#                                       * 1.1654)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.910e+04
# Progress: 1024 / 2000 total iterations (51.200%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.584e-01  0.000e+00  y = 1.0814
# 3           2.272e-01  6.441e-02  y = 0.59403 / x₁
# 4           2.193e-01  3.538e-02  y = inv(x₁ + 0.3437)
# 5           1.592e-01  3.206e-01  y = inv(log(x₀ + -4.7862))
# 7           1.408e-01  6.134e-02  y = exp(inv(cube(x₀ + -5.2448)))
# 8           1.292e-01  8.554e-02  y = exp(square(log(log(x₀ - 4.8065))))
# 9           1.191e-01  8.178e-02  y = exp(inv(cube(cube(x₀ + -5.2509))))
# 10          1.178e-01  1.116e-02  y = exp(cube(square(log(log(x₀ - 4.8087)))))
# 11          1.114e-01  5.533e-02  y = exp(tanh(log(x₁) * log(log(x₀ + -5.1872))))
# 13          1.008e-01  5.022e-02  y = exp(log(log(x₀ + -5.1732)) * tanh(x₁ + log(x₁)))
# 15          9.858e-02  1.105e-02  y = exp(tanh(log(log(-5.2256 + x₀)) * (1.0895 + log(square...
#                                       (x₁)))))
# 16          9.820e-02  3.857e-03  y = exp(tanh(log(log(x₀ + -5.2256)) * (exp(-0.032434) + lo...
#                                       g(square(x₁)))))
# 17          9.735e-02  8.667e-03  y = exp(tanh(log(log(-5.2256 + x₀)) * log(cube(x₁ + (x₁ * ...
#                                       0.79871)))))
# 18          9.713e-02  2.269e-03  y = exp(tanh(((x₁ * exp(0.69665)) + log(square(x₁))) * log...
#                                       (log(x₀ + -5.2256))))
# 19          9.691e-02  2.258e-03  y = exp(tanh(log(log(x₀ + -5.2196)) * log(square(x₁ + (cub...
#                                       e(x₁) * 2.6621)))))
# 22          9.670e-02  7.337e-04  y = exp(tanh(log((inv(1.733) + cube(x₁ - (0.1077 - x₁))) *...
#                                        x₁) * log(log(-5.2256 + x₀))))
# 23          9.299e-02  3.904e-02  y = exp(tanh(log(log(x₀ + -5.2256)) * log((cube(cube(x₁ - ...
#                                       (0.1077 - x₁))) + 0.43191) * x₁)))
# 24          8.420e-02  9.938e-02  y = exp(tanh(square(square(log(log(-5.1591 + x₀)) / (inv(0...
#                                       .70019) - (cube(x₁) * (exp(x₁) * x₀)))))))
# 25          6.791e-02  2.150e-01  y = exp(tanh(log(log((x₀ / 0.96902) - 4.8054)) * cube(log(...
#                                       cube(log(square(log(x₀ + -5.8806))) * -1.2192)))))
# 27          5.788e-02  7.994e-02  y = exp(tanh(cube(cube(log(log(square(square(log(x₀ + -5.8...
#                                       806)))) * -1.0855))) * log(log((x₀ / 0.96902) - 4.8054))))
# 29          5.689e-02  8.624e-03  y = exp(tanh(cube(cube(log(log(square(square(log(x₀ + -5.8...
#                                       806)))) * -1.0855))) * (log(log((x₀ / 0.96902) - 4.8054)) ...
#                                       * 1.1654)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.070e+04
# Progress: 1212 / 2000 total iterations (60.600%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.584e-01  0.000e+00  y = 1.0814
# 3           2.272e-01  6.441e-02  y = 0.59403 / x₁
# 4           2.193e-01  3.538e-02  y = inv(x₁ + 0.3437)
# 5           1.592e-01  3.206e-01  y = inv(log(x₀ + -4.7862))
# 7           1.408e-01  6.134e-02  y = exp(inv(cube(x₀ + -5.2448)))
# 8           1.292e-01  8.555e-02  y = exp(square(log(log(x₀ - 4.8067))))
# 9           1.139e-01  1.266e-01  y = exp(log(x₁) * log(log(x₀ + -4.91)))
# 11          1.017e-01  5.639e-02  y = exp(log(log(x₀ + -5.1649)) * (x₁ + log(x₁)))
# 13          1.008e-01  4.665e-03  y = exp(log(log(x₀ + -5.1732)) * tanh(x₁ + log(x₁)))
# 15          9.789e-02  1.453e-02  y = exp(tanh((log(square(x₁)) + 0.99578) * log(log(x₀ + -5...
#                                       .2462))))
# 16          8.091e-02  1.905e-01  y = exp(tanh(tanh(inv(log(x₁) + x₁)) * log(log(x₀ + -5.244...
#                                       9))))
# 17          7.725e-02  4.632e-02  y = exp(tanh(tanh(inv(inv(1.8784) + log(x₁))) * log(log(x₀...
#                                        + -5.2449))))
# 18          7.363e-02  4.796e-02  y = exp(tanh(inv(log(x₁) + tanh(0.74118))) * tanh(log(log(...
#                                       -5.2449 + x₀))))
# 20          6.737e-02  4.445e-02  y = exp(tanh((x₁ / (log(square(x₁ * 0.79845)) + exp(x₁))) ...
#                                       * log(log(x₀ + -5.2256))))
# 22          6.493e-02  1.847e-02  y = exp(tanh((x₁ / (log(square(x₁ * 0.79845)) + exp(x₁))) ...
#                                       * (log(log(x₀ + -5.2256)) - -0.010741)))
# 27          5.788e-02  2.299e-02  y = exp(tanh(cube(cube(log(log(square(square(log(x₀ + -5.8...
#                                       806)))) * -1.0855))) * log(log((x₀ / 0.96902) - 4.8054))))
# 29          5.689e-02  8.624e-03  y = exp(tanh(cube(cube(log(log(square(square(log(x₀ + -5.8...
#                                       806)))) * -1.0855))) * (log(log((x₀ / 0.96902) - 4.8054)) ...
#                                       * 1.1654)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.140e+04
# Progress: 1406 / 2000 total iterations (70.300%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.584e-01  0.000e+00  y = 1.0814
# 3           2.272e-01  6.441e-02  y = 0.59403 / x₁
# 4           2.193e-01  3.538e-02  y = inv(x₁ + 0.3437)
# 5           1.592e-01  3.206e-01  y = inv(log(x₀ + -4.7862))
# 7           1.408e-01  6.134e-02  y = exp(inv(cube(x₀ + -5.2448)))
# 8           1.292e-01  8.555e-02  y = exp(square(log(log(x₀ - 4.8067))))
# 9           1.139e-01  1.266e-01  y = exp(log(x₁) * log(log(x₀ + -4.91)))
# 11          1.017e-01  5.639e-02  y = exp(log(log(x₀ + -5.1649)) * (x₁ + log(x₁)))
# 13          1.003e-01  7.124e-03  y = exp(tanh(log(log(x₀ + -5.2449)) * (x₁ + log(x₁))))
# 15          9.789e-02  1.207e-02  y = exp(tanh((log(square(x₁)) + 0.99578) * log(log(x₀ + -5...
#                                       .2462))))
# 16          7.393e-02  2.807e-01  y = exp(tanh(log(log(x₀ + -5.2449)) / tanh(inv(0.62985 + l...
#                                       og(x₁)))))
# 17          7.367e-02  3.500e-03  y = exp(tanh(log(log(x₀ + -5.2449)) / inv(tanh(inv(0.62985...
#                                        + log(x₁))))))
# 18          7.361e-02  8.253e-04  y = exp(tanh(log(log(x₀ + -5.2449))) * tanh(inv(tanh(0.807...
#                                       29) + log(x₁))))
# 20          4.913e-02  2.022e-01  y = exp(((log(log(x₀ + -5.1354)) * x₁) / (log(square(x₁ * ...
#                                       0.83121)) + exp(x₁))) * 0.55586)
# 28          4.563e-02  9.236e-03  y = exp((((x₁ + 0.84246) * x₁) / (exp(x₁) + log(square(x₁ ...
#                                       * -0.82457)))) * (tanh(x₁) * log(log((x₀ - -0.060714) + -5...
#                                       .2187))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.120e+04
# Progress: 1593 / 2000 total iterations (79.650%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.584e-01  0.000e+00  y = 1.0814
# 3           2.272e-01  6.441e-02  y = 0.59403 / x₁
# 4           2.193e-01  3.538e-02  y = inv(x₁ + 0.3437)
# 5           1.592e-01  3.206e-01  y = inv(log(x₀ + -4.7862))
# 7           1.408e-01  6.134e-02  y = exp(cube(inv(x₀ + -5.2449)))
# 8           1.292e-01  8.555e-02  y = exp(square(log(log(x₀ - 4.8067))))
# 9           1.139e-01  1.266e-01  y = exp(log(x₁) * log(log(x₀ + -4.91)))
# 11          1.017e-01  5.639e-02  y = exp(log(log(x₀ + -5.1649)) * (x₁ + log(x₁)))
# 13          1.001e-01  7.935e-03  y = exp(tanh(log(log(x₀ + -5.2462)) * (log(x₁) + x₁)))
# 15          9.785e-02  1.148e-02  y = exp(tanh(log(log(x₀ + -5.2462)) * (log(square(x₁)) + 1...
#                                       .0253)))
# 16          7.393e-02  2.803e-01  y = exp(tanh(log(log(x₀ + -5.2449)) / tanh(inv(0.62985 + l...
#                                       og(x₁)))))
# 17          7.367e-02  3.500e-03  y = exp(tanh(log(log(x₀ + -5.2449)) / inv(tanh(inv(0.62985...
#                                        + log(x₁))))))
# 18          7.361e-02  8.253e-04  y = exp(tanh(log(log(x₀ + -5.2449))) * tanh(inv(tanh(0.807...
#                                       29) + log(x₁))))
# 20          4.702e-02  2.242e-01  y = exp((x₁ * (log(log(x₀ + -5.1858)) / (log(square(x₁ * -...
#                                       0.83033)) + exp(x₁)))) * x₁)
# 22          4.571e-02  1.414e-02  y = exp((log(log(x₀ + -5.1095)) * ((x₁ + 0.18985) / (log(s...
#                                       quare(x₁ * -0.82561)) + exp(x₁)))) * x₁)
# 23          4.561e-02  2.026e-03  y = exp(x₁ * ((log(log(x₀ + -5.1206)) / (log(square(x₁ * -...
#                                       0.82782)) + exp(x₁))) * (x₁ + inv(x₀))))
# 25          4.416e-02  1.618e-02  y = exp((x₁ * (x₁ + inv(x₀))) * ((log(log(x₀ + -5.1205)) /...
#                                        (log(square(x₁ * -0.82886)) + exp(x₁))) - 0.034357))
# 27          4.330e-02  9.788e-03  y = exp((inv(x₀) + (x₁ * (x₁ * 0.97092))) * ((log(log(x₀ +...
#                                        -5.0328)) / (log(square(x₁ * -0.83293)) + exp(x₁))) - 0.1...
#                                       2634))
# 30          4.294e-02  2.830e-03  y = exp(((x₁ + inv(x₀)) * (x₁ * 1.2361)) * (((log(log(x₀ +...
#                                        -5.0619)) / (exp(x₁) + log(square(x₁ * -0.82828)))) - inv...
#                                       (x₀)) - -0.041967))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.970e+04
# Progress: 1709 / 2000 total iterations (85.450%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.584e-01  0.000e+00  y = 1.0814
# 3           2.272e-01  6.441e-02  y = 0.59403 / x₁
# 4           2.193e-01  3.538e-02  y = inv(x₁ + 0.3437)
# 5           1.592e-01  3.206e-01  y = inv(log(x₀ + -4.7862))
# 7           1.408e-01  6.134e-02  y = exp(cube(inv(x₀ + -5.2449)))
# 8           1.281e-01  9.409e-02  y = exp(log(log(x₀ + -5.2449)) / -5.2449)
# 9           1.139e-01  1.180e-01  y = exp(log(x₁) * log(log(x₀ + -4.91)))
# 11          1.017e-01  5.639e-02  y = exp(log(log(x₀ + -5.1649)) * (x₁ + log(x₁)))
# 13          1.001e-01  7.935e-03  y = exp(tanh(log(log(x₀ + -5.2462)) * (log(x₁) + x₁)))
# 14          9.867e-02  1.467e-02  y = exp(tanh((log(x₁) + x₁) * (log(x₀ + -6.2364) - 0.56334...
#                                       )))
# 15          9.785e-02  8.287e-03  y = exp(tanh(log(log(x₀ + -5.2462)) * (log(square(x₁)) + 1...
#                                       .0253)))
# 16          7.363e-02  2.844e-01  y = exp(tanh(inv(log(x₁) + 0.62985)) * tanh(log(log(x₀ + -...
#                                       5.2449))))
# 18          7.091e-02  1.883e-02  y = exp(tanh(log(log(x₀ + -5.2449)) / tanh(tanh(inv(0.6298...
#                                       5 + log(x₁))))))
# 19          7.062e-02  4.179e-03  y = exp(tanh(log(log(x₀ + -5.2449)) / tanh(inv(tanh(inv(0....
#                                       62985 + log(x₁)))))))
# 20          4.702e-02  4.068e-01  y = exp((log(log(-5.1858 + x₀)) / (log(square(x₁ * -0.8303...
#                                       3)) + exp(x₁))) * (x₁ * x₁))
# 22          4.571e-02  1.414e-02  y = exp((log(log(x₀ + -5.1095)) * ((x₁ + 0.18985) / (log(s...
#                                       quare(x₁ * -0.82561)) + exp(x₁)))) * x₁)
# 23          4.561e-02  2.026e-03  y = exp(x₁ * ((log(log(x₀ + -5.1206)) / (log(square(x₁ * -...
#                                       0.82782)) + exp(x₁))) * (x₁ + inv(x₀))))
# 24          4.510e-02  1.129e-02  y = exp(((x₁ + 0.18985) / (log(square(x₁ * -0.82561)) + ex...
#                                       p(x₁))) * (x₁ * log(log(x₀ + -5.1095)))) * 0.9868
# 25          4.416e-02  2.107e-02  y = exp((x₁ * (x₁ + inv(x₀))) * ((log(log(x₀ + -5.1205)) /...
#                                        (log(square(x₁ * -0.82886)) + exp(x₁))) - 0.034357))
# 27          4.330e-02  9.788e-03  y = exp((inv(x₀) + (x₁ * (x₁ * 0.97092))) * ((log(log(x₀ +...
#                                        -5.0328)) / (log(square(x₁ * -0.83293)) + exp(x₁))) - 0.1...
#                                       2634))
# 28          4.289e-02  9.515e-03  y = exp(((x₁ + inv(x₀)) * x₁) * (((log(log(x₀ + -5.0621)) ...
#                                       * 1.2362) / (exp(x₁) + log(square(x₁ * -0.82916)))) - inv(...
#                                       x₀)))
# 30          4.289e-02  7.952e-05  y = exp(((x₁ + inv(x₀)) * x₁) * (((log(log(x₀ + -5.0621)) ...
#                                       * 1.2362) / (exp(x₁) + log(square(x₁ * -0.82916)))) - inv(...
#                                       x₀ - -0.04197)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.960e+04
# Progress: 1895 / 2000 total iterations (94.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.584e-01  0.000e+00  y = 1.0814
# 3           2.272e-01  6.441e-02  y = 0.59403 / x₁
# 4           2.193e-01  3.538e-02  y = inv(x₁ + 0.3437)
# 5           1.592e-01  3.206e-01  y = inv(log(x₀ + -4.7862))
# 7           1.408e-01  6.134e-02  y = exp(cube(inv(x₀ + -5.2449)))
# 8           1.281e-01  9.409e-02  y = exp(log(log(x₀ + -5.2449)) / -5.2449)
# 9           1.139e-01  1.180e-01  y = exp(log(x₁) * log(log(x₀ + -4.91)))
# 11          1.017e-01  5.640e-02  y = exp((x₁ + log(x₁)) * log(log(x₀ + -5.1633)))
# 13          1.001e-01  7.926e-03  y = exp(tanh(log(log(x₀ + -5.2462)) * (log(x₁) + x₁)))
# 14          9.867e-02  1.467e-02  y = exp(tanh((log(x₁) + x₁) * (log(x₀ + -6.2364) - 0.56334...
#                                       )))
# 15          9.785e-02  8.287e-03  y = exp(tanh(log(log(x₀ + -5.2462)) * (log(square(x₁)) + 1...
#                                       .0253)))
# 16          7.363e-02  2.844e-01  y = exp(tanh(inv(log(x₁) + 0.62985)) * tanh(log(log(x₀ + -...
#                                       5.2449))))
# 18          7.084e-02  1.936e-02  y = exp(tanh(log(log(x₀ + -5.2389)) / tanh(tanh(inv(log(x₁...
#                                       ) + 0.63546)))))
# 19          7.062e-02  3.127e-03  y = exp(tanh(log(log(x₀ + -5.2449)) / tanh(inv(tanh(inv(0....
#                                       62985 + log(x₁)))))))
# 20          4.702e-02  4.068e-01  y = exp((log(log(-5.1858 + x₀)) / (log(square(x₁ * -0.8303...
#                                       3)) + exp(x₁))) * (x₁ * x₁))
# 22          4.561e-02  1.520e-02  y = exp((((x₁ * log(log(x₀ + -5.0412))) / (log(square(x₁ *...
#                                        -0.83141)) + exp(x₁))) - 0.087168) / 1.2533)
# 24          4.364e-02  2.210e-02  y = exp((((log(log(x₀ + -5.0906)) / ((log(square(x₁ * -0.8...
#                                       2297)) + exp(x₁)) * 0.63246)) + -0.11131) * x₁) * x₁)
# 25          4.342e-02  4.874e-03  y = exp((inv(x₀) + (x₁ * x₁)) * ((log(log(x₀ + -5.0328)) /...
#                                        (log(square(x₁ * -0.83293)) + exp(x₁))) - 0.12634))
# 26          4.319e-02  5.440e-03  y = exp((inv(x₀) + (x₁ * x₁)) * ((log(log(x₀ + -5.0328)) /...
#                                        (log(square(x₁ * -0.83293)) + exp(x₁))) - inv(x₀)))
# 28          4.289e-02  3.409e-03  y = exp(((x₁ + inv(x₀)) * x₁) * ((1.2362 * (log(log(-5.062...
#                                       1 + x₀)) / (exp(x₁) + log(square(x₁ * -0.82916))))) - inv(...
#                                       x₀)))
# 29          4.289e-02  1.433e-04  y = exp(((((log(log(x₀ + -5.0851)) / (exp(x₁) + log(square...
#                                       (x₁ * -0.82694)))) - 0.078777) * 1.2601) * x₁) * (x₁ + inv...
#                                       (x₀ + 3.0652)))
# 30          4.285e-02  8.345e-04  y = exp((x₁ + inv(x₀)) * (x₁ * ((1.2362 * (log(log(-5.0621...
#                                        + x₀)) / (exp(x₁) + log(square(x₁ * -0.82916))))) - inv(x...
#                                       ₀ + 0.31489))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.584e-01  0.000e+00  y = 1.0814
# 3           2.272e-01  6.441e-02  y = 0.59403 / x₁
# 4           2.193e-01  3.538e-02  y = inv(x₁ + 0.3437)
# 5           1.592e-01  3.206e-01  y = inv(log(x₀ + -4.7862))
# 7           1.408e-01  6.134e-02  y = exp(cube(inv(x₀ + -5.2449)))
# 8           1.277e-01  9.731e-02  y = exp(log(log(x₀ + -5.2449)) / -5.1729)
# 9           1.139e-01  1.148e-01  y = exp(log(x₁) * log(log(x₀ + -4.91)))
# 11          1.017e-01  5.640e-02  y = exp((x₁ + log(x₁)) * log(log(x₀ + -5.1633)))
# 13          1.001e-01  7.926e-03  y = exp(tanh(log(log(x₀ + -5.2462)) * (log(x₁) + x₁)))
# 14          9.867e-02  1.467e-02  y = exp(tanh((log(x₁) + x₁) * (log(x₀ + -6.2364) - 0.56334...
#                                       )))
# 15          9.785e-02  8.287e-03  y = exp(tanh(log(log(x₀ + -5.2462)) * (log(square(x₁)) + 1...
#                                       .0253)))
# 16          7.363e-02  2.844e-01  y = exp(tanh(inv(log(x₁) + 0.62985)) * tanh(log(log(x₀ + -...
#                                       5.2449))))
# 18          7.084e-02  1.936e-02  y = exp(tanh(log(log(x₀ + -5.2389)) / tanh(tanh(inv(log(x₁...
#                                       ) + 0.63546)))))
# 19          7.055e-02  4.081e-03  y = exp(tanh(log(log(-5.2389 + x₀)) / tanh(inv(tanh(inv(lo...
#                                       g(x₁) + 0.63546))))))
# 20          4.702e-02  4.058e-01  y = exp((log(log(-5.1858 + x₀)) / (log(square(x₁ * -0.8303...
#                                       3)) + exp(x₁))) * (x₁ * x₁))
# 22          4.559e-02  1.541e-02  y = exp((((log(log(x₀ + -5.043)) / (exp(x₁) + log(square(x...
#                                       ₁ * -0.83135)))) * x₁) - 0.085621) / 1.2607)
# 24          4.323e-02  2.652e-02  y = exp((x₁ * ((log(log(x₀ + -5.0821)) / ((log(square(x₁ *...
#                                        -0.82622)) + exp(x₁)) * 0.63447)) + -0.11096)) * x₁)
# 26          4.319e-02  5.237e-04  y = exp((inv(x₀) + (x₁ * x₁)) * ((log(log(x₀ + -5.0328)) /...
#                                        (log(square(x₁ * -0.83293)) + exp(x₁))) - inv(x₀)))
# 28          4.289e-02  3.409e-03  y = exp(((x₁ + inv(x₀)) * x₁) * ((1.2362 * (log(log(-5.062...
#                                       1 + x₀)) / (exp(x₁) + log(square(x₁ * -0.82916))))) - inv(...
#                                       x₀)))
# 29          4.289e-02  1.433e-04  y = exp(((((log(log(x₀ + -5.0851)) / (exp(x₁) + log(square...
#                                       (x₁ * -0.82694)))) - 0.078777) * 1.2601) * x₁) * (x₁ + inv...
#                                       (x₀ + 3.0652)))
# 30          4.276e-02  3.091e-03  y = exp((x₁ + inv(x₀)) * (x₁ * (((1.2362 * log(log(-5.0621...
#                                        + x₀))) / (exp(x₁) + log(square(x₁ * -0.82916)))) - inv(x...
#                                       ₀ + x₁))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          1.0813742
# 	1         0.064410                                    0.59402996 / x1
# 	2         0.035380                               inv(x1 + 0.34370077)
# 	3         0.320604                           inv(log(x0 + -4.786181))
# 	4         0.061344                      exp(cube(inv(x0 + -5.24489)))
# 	5         0.097309         exp(log(log(x0 + -5.244945)) / -5.1728654)
# 	6         0.114832           exp(log(x1) * log(log(x0 + -4.9099708)))
# 	7         0.056400    exp((x1 + log(x1)) * log(log(x0 + -5.1632667)))
# 	8         0.007926  exp(tanh(log(log(x0 + -5.246156)) * (log(x1) +...
# 	9         0.014668  exp(tanh((log(x1) + x1) * (log(x0 + -6.2364483...
# 	10        0.008287  exp(tanh(log(log(x0 + -5.246156)) * (log(squar...
# 	11        0.284352  exp(tanh(inv(log(x1) + 0.62985474)) * tanh(log...
# 	12        0.019355  exp(tanh(log(log(x0 + -5.238939)) / tanh(tanh(...
# 	13        0.004081  exp(tanh(log(log(-5.238939 + x0)) / tanh(inv(t...
# 	14  >>>>  0.405816  exp((log(log(-5.1858373 + x0)) / (log(square(x...
# 	15        0.015414  exp((((log(log(x0 + -5.0429616)) / (exp(x1) + ...
# 	16        0.026523  exp((x1 * ((log(log(x0 + -5.0820527)) / ((log(...
# 	17        0.000524  exp((inv(x0) + (x1 * x1)) * ((log(log(x0 + -5....
# 	18        0.003409  exp(((x1 + inv(x0)) * x1) * ((1.2361686 * (log...
# 	19        0.000143  exp(((((log(log(x0 + -5.085079)) / (exp(x1) + ...
# 	20        0.003091  exp((x1 + inv(x0)) * (x1 * (((1.2361686 * log(...
#
# 	        loss  complexity
# 	0   0.258446           1
# 	1   0.227209           3
# 	2   0.219311           4
# 	3   0.159156           5
# 	4   0.140780           7
# 	5   0.127726           8
# 	6   0.113870           9
# 	7   0.101723          11
# 	8   0.100124          13
# 	9   0.098666          14
# 	10  0.097851          15
# 	11  0.073633          16
# 	12  0.070837          18
# 	13  0.070549          19
# 	14  0.047016          20
# 	15  0.045589          22
# 	16  0.043233          24
# 	17  0.043188          26
# 	18  0.042895          28
# 	19  0.042889          29
# 	20  0.042756          30
# ]
#   - outputs/20250919_202142_rNbjit/hall_of_fame.csv

# %%
# 获取 PySR 找到的所有方程（这是一个 Pandas DataFrame）
all_equations = model.equations_

# 根据损失（loss）从低到高排序
sorted_by_loss = all_equations.sort_values(by='loss', ascending=True)
print("按损失排序的前10个方程:")
display(sorted_by_loss.head(10))

# 或者，你也可以根据得分（score）排序，它能更好地平衡复杂度和损失
sorted_by_score = all_equations.sort_values(by='score', ascending=False)
print("按得分排序的前10个方程:")
display(sorted_by_score.head(10))
# Out:
# 按损失排序的前10个方程:
#     complexity      loss                                           equation  \
# 20          30  0.042756  exp((x1 + inv(x0)) * (x1 * (((1.2361686 * log(...
# 19          29  0.042889  exp(((((log(log(x0 + -5.085079)) / (exp(x1) + ...
# 18          28  0.042895  exp(((x1 + inv(x0)) * x1) * ((1.2361686 * (log...
# 17          26  0.043188  exp((inv(x0) + (x1 * x1)) * ((log(log(x0 + -5....
# 16          24  0.043233  exp((x1 * ((log(log(x0 + -5.0820527)) / ((log(...
# 15          22  0.045589  exp((((log(log(x0 + -5.0429616)) / (exp(x1) + ...
# 14          20  0.047016  exp((log(log(-5.1858373 + x0)) / (log(square(x...
# 13          19  0.070549  exp(tanh(log(log(-5.238939 + x0)) / tanh(inv(t...
# 12          18  0.070837  exp(tanh(log(log(x0 + -5.238939)) / tanh(tanh(...
# 11          16  0.073633  exp(tanh(inv(log(x1) + 0.62985474)) * tanh(log...
#
#        score                                       sympy_format  \
# 20  0.003091  exp(x1*(x1 + 1/x0)*(1.2361686*log(log(x0 - 5.0...
# 19  0.000143  exp(x1*(-0.09926369950028 + 1.2600658*log(log(...
# 18  0.003409  exp(x1*(x1 + 1/x0)*(1.2361686*log(log(x0 - 5.0...
# 17  0.000524  exp((x1**2 + 1/x0)*(log(log(x0 - 5.0327706))/(...
# 16  0.026523  exp(x1**2*(-0.11095682 + log(log(x0 - 5.082052...
# 15  0.015414  0.934339811982409*exp(0.793209051752687*x1*log...
# 14  0.405816  exp(x1**2*log(log(x0 - 5.1858373))/(exp(x1) + ...
# 13  0.004081  exp(tanh(log(log(x0 - 5.238939))/tanh(1/tanh(1...
# 12  0.019355  exp(tanh(log(log(x0 - 5.238939))/tanh(tanh(1/(...
# 11  0.284352  exp(tanh(1/(log(x1) + 0.62985474))*tanh(log(lo...
#
#                                         lambda_format
# 20  PySRFunction(X=>exp(x1*(x1 + 1/x0)*(1.2361686*...
# 19  PySRFunction(X=>exp(x1*(-0.09926369950028 + 1....
# 18  PySRFunction(X=>exp(x1*(x1 + 1/x0)*(1.2361686*...
# 17  PySRFunction(X=>exp((x1**2 + 1/x0)*(log(log(x0...
# 16  PySRFunction(X=>exp(x1**2*(-0.11095682 + log(l...
# 15  PySRFunction(X=>0.934339811982409*exp(0.793209...
# 14  PySRFunction(X=>exp(x1**2*log(log(x0 - 5.18583...
# 13  PySRFunction(X=>exp(tanh(log(log(x0 - 5.238939...
# 12  PySRFunction(X=>exp(tanh(log(log(x0 - 5.238939...
# 11  PySRFunction(X=>exp(tanh(1/(log(x1) + 0.629854...
# 按得分排序的前10个方程:
#     complexity      loss                                           equation  \
# 14          20  0.047016  exp((log(log(-5.1858373 + x0)) / (log(square(x...
# 3            5  0.159156                           inv(log(x0 + -4.786181))
# 11          16  0.073633  exp(tanh(inv(log(x1) + 0.62985474)) * tanh(log...
# 6            9  0.113870           exp(log(x1) * log(log(x0 + -4.9099708)))
# 5            8  0.127726         exp(log(log(x0 + -5.244945)) / -5.1728654)
# 1            3  0.227209                                    0.59402996 / x1
# 4            7  0.140780                      exp(cube(inv(x0 + -5.24489)))
# 7           11  0.101723    exp((x1 + log(x1)) * log(log(x0 + -5.1632667)))
# 2            4  0.219311                               inv(x1 + 0.34370077)
# 16          24  0.043233  exp((x1 * ((log(log(x0 + -5.0820527)) / ((log(...
#
#        score                                       sympy_format  \
# 14  0.405816  exp(x1**2*log(log(x0 - 5.1858373))/(exp(x1) + ...
# 3   0.320604                               1/log(x0 - 4.786181)
# 11  0.284352  exp(tanh(1/(log(x1) + 0.62985474))*tanh(log(lo...
# 6   0.114832              exp(log(x1)*log(log(x0 - 4.9099708)))
# 5   0.097309           log(x0 - 5.244945)**(-0.193316454744792)
# 1   0.064410                                      0.59402996/x1
# 4   0.061344  exp(0.00693091938063737/(0.190661767930309*x0 ...
# 7   0.056400       exp((x1 + log(x1))*log(log(x0 - 5.1632667)))
# 2   0.035380                                1/(x1 + 0.34370077)
# 16  0.026523  exp(x1**2*(-0.11095682 + log(log(x0 - 5.082052...
#
#                                         lambda_format
# 14  PySRFunction(X=>exp(x1**2*log(log(x0 - 5.18583...
# 3               PySRFunction(X=>1/log(x0 - 4.786181))
# 11  PySRFunction(X=>exp(tanh(1/(log(x1) + 0.629854...
# 6   PySRFunction(X=>exp(log(x1)*log(log(x0 - 4.909...
# 5   PySRFunction(X=>log(x0 - 5.244945)**(-0.193316...
# 1                      PySRFunction(X=>0.59402996/x1)
# 4   PySRFunction(X=>exp(0.00693091938063737/(0.190...
# 7   PySRFunction(X=>exp((x1 + log(x1))*log(log(x0 ...
# 2                PySRFunction(X=>1/(x1 + 0.34370077))
# 16  PySRFunction(X=>exp(x1**2*(-0.11095682 + log(l...

# %%
# manually select the best equation
best_equation_info = sorted_by_score.iloc[1]
best_equation_str = best_equation_info['equation']

print("找到的最佳通用方程:")
print(f"Equation: {best_equation_str}")
print(f"Loss: {best_equation_info['loss']:.4f}")
print(f"Score: {best_equation_info['score']:.4f}")

best_equation = best_equation_info['sympy_format']

p_km_relative, p_vmax_relative = sympy.symbols('x0 x1')
eval_func = sympy.lambdify(
    [p_km_relative, p_vmax_relative],
    best_equation,
    modules=['numpy']
)
# Out:
# 找到的最佳通用方程:
# Equation: inv(log(x0 + -4.786181))
# Loss: 0.1592
# Score: 0.3206

# %%
import plotly.graph_objects as go
from sklearn.metrics import r2_score

# 计算 R²
y_pred = eval_func(X[:, 0], X[:, 1])
r2 = r2_score(y, y_pred)

# 网格
# x0_vals = np.linspace(df['P_Km_relative'].min(), df['P_Km_relative'].max(), 50)
# x1_vals = np.linspace(df['P_Vmax_relative'].min(), df['P_Vmax_relative'].max(), 50)
# make the grid a bit larger for better visualization
x0_vals = np.linspace(df['P_Km_relative'].min()*0.5, df['P_Km_relative'].max()*1.1, 50)
x1_vals = np.linspace(df['P_Vmax_relative'].min()*0.5, df['P_Vmax_relative'].max()*1.1, 50)

X0, X1 = np.meshgrid(x0_vals, x1_vals)
Y_pred = eval_func(X0, X1)

fig = go.Figure()

# 数据点
fig.add_trace(go.Scatter3d(
    x=X[:, 0],
    y=X[:, 1],
    z=y,
    mode='markers',
    marker=dict(size=4, color='blue', opacity=0.6),
    name="Actual Data"
))

# 曲面
fig.add_trace(go.Surface(
    x=x0_vals, y=x1_vals, z=Y_pred,
    colorscale='Viridis',
    opacity=0.7,
    name="Predicted Surface"
))

# 在标题里加方程 & R²（字符格式）
fig.update_layout(
    scene=dict(
        xaxis_title="E (x0)",
        yaxis_title="k (x1)",
        zaxis_title="Km (y)",
    ),
    title=f"Best Equation Fit<br>Eq: {best_equation_str}<br>R² = {r2:.3f}"
)

fig.show()
# Out:
# <lambdifygenerated-2>:2: RuntimeWarning: invalid value encountered in log
#   return log(x0 - 4.786181)**(-1.0)

# %%
# 网格
x0_vals = np.linspace(df['P_Km_relative'].min(), df['P_Km_relative'].max(), 100)
x1_vals = np.linspace(df['P_Vmax_relative'].min(), df['P_Vmax_relative'].max(), 100)
X0, X1 = np.meshgrid(x0_vals, x1_vals)
Y_pred = eval_func(X0, X1)

fig = go.Figure()

# 等高线图
fig.add_trace(go.Contour(
    x=x0_vals,
    y=x1_vals,
    z=Y_pred,
    colorscale="Viridis",
    contours=dict(showlabels=True),
    colorbar=dict(title="Predicted y"),
    opacity=0.8,
    name="Prediction Contour"
))

# 真实数据点
fig.add_trace(go.Scatter(
    x=df['P_Km_relative'],
    y=df['P_Vmax_relative'],
    mode="markers",
    marker=dict(size=6, color=y, colorscale="Viridis", showscale=False),
    name="Actual Data"
))

fig.update_layout(
    xaxis_title="P_Km_relative (x0)",
    yaxis_title="P_Vmax_relative (x1)",
    title=f"Best Equation Contour Plot<br>Eq: {best_equation_str}<br>R² = {r2:.3f}"
)

fig.show()
# Out:
# Error in callback _flush_stdio (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/avYrV/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 4094-4095: unexpected end of data
